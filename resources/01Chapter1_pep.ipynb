# %% [markdown]
# <a href="https://colab.research.google.com/github/ag999git/001-Python-book-2026/blob/main/colab-nb/01Chapter1_pep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 1: Python Basics 1
#
# ## Companion notebook for the book
#
# This notebook holds the code examples of Chapter 1. You do not need to type them. Just run them, read the explanations, and then change the code to see what happens. Changing code and watching the result is the fastest way to learn.
#
# ### How this notebook is arranged
#
# - Each code example from the book is in its own code cell. The code is the same as the printed code.
# - Before every example there is a text cell. It tells you what the code does, how it does it, why it matters, and what you should learn from it.
# - Some examples also have a text cell after them. Its heading starts with "Notes on Example" and the example number, so you always know which code cell it talks about.
# - A short "Beyond the Book" section at the end adds a few extra ideas. You can skip it on the first reading.
#
# ### How to run the code
#
# 1. Click inside a code cell.
# 2. Press **Shift + Enter**, or click the round Run button on the left of the cell.
# 3. The result appears just below the cell.
#
# Run the cells from top to bottom. Some later cells use variables made by earlier cells.
#
# Two cells in this notebook are **meant** to fail with an error (Example 21 and the last cell of "Beyond the Book"). This is on purpose, so you can see what the error looks like. If you use **Runtime > Run all** and it stops at such a cell, click the next cell and choose **Runtime > Run after**.
#
# ### How to read the flowcharts
#
# The steps in each flowchart are numbered: they go 1, 2, 3 and so on. When the flow splits into two paths, one path uses the letter A (4A, 5A ...) and the other uses the letter B (4B, 5B ...). If the two paths join again, the numbering goes back to plain numbers.

# %% [markdown]
# ## Chapter map
#
# The table shows which book section each example belongs to.
#
# | Book section | Topic | Examples in this notebook |
# |---|---|---|
# | 1.2 and 1.3 | Interpreter, compiler, command line and script mode | Background only (no code) |
# | 1.8 | Using Python as a calculator | Examples 1 to 4 |
# | 1.9 | The `print()` function | Example 5 |
# | 1.10 | Running Python from a script file | Example 6 |
# | 1.11 | Single-line and multi-line comments | Examples 7 and 8 |
# | 1.11.1 | Explicit and implicit line continuation, semicolons | Examples 9 to 12 |
# | 1.13 | Python keywords | Example 13 |
# | 1.14 and 1.15 | Identifiers, naming conventions, PEP 8 | Example 14 |
# | 1.16.1 and 1.16.2 | Variables and assignment | Examples 15 to 17 |
# | 1.16.3 and 1.16.4 | References and shared references | Examples 18 to 20 |
# | 1.16.5 | Variables and identifiers, `NameError`, `id()` | Examples 21 and 22 |
# | Extra | Beyond the Book | Four short extras |

# %% [markdown]
# ## Background: how Python runs your code (Sections 1.2 and 1.3)
#
# There is no code in these sections, but one idea is needed for everything that follows.
#
# A computer cannot run Python text directly. Some program has to turn your code into actions. There are two ways to do this.
#
# - **Compiler:** reads the whole program first, translates all of it into a new file (object code or an executable), and only then is that file run. C++ works this way.
# - **Interpreter:** reads your program a little at a time and runs each part straight away. There is no separate translated file for you to manage. Python works this way.
#
# ```mermaid
# flowchart LR
#     A1["1A. Source code (Python)"] --> A2["2A. Interpreter reads and runs it"] --> A3["3A. Output"]
#     B1["1B. Source code (C++)"] --> B2["2B. Compiler translates all of it"] --> B3["3B. Object code or executable"] --> B4["4B. Executable is run"] --> B5["5B. Output"]
# ```
#
# Path A is an interpreted language like Python. Path B is a compiled language like C++.
#
# Because Python is interpreted, you can use it in two ways:
#
# | | Interactive mode (command line) | Script mode (.py file) |
# |---|---|---|
# | How you use it | Type one line, press Enter, see the result at once | Write many lines in a file, save it, then run the whole file |
# | Good for | Quick tests, trying out an idea, using Python as a calculator | Real programs you want to keep, share and run again |
# | Is your code saved? | No | Yes |
#
# A notebook like this one sits in between. Each cell can be run on its own, like interactive mode. But all the cells are saved in one file, like a script.

# %% [markdown]
# ## Section 1.8: Using Python as a calculator
#
# The book shows four small calculations typed into a Jupyter Notebook (Figure 1.4). Examples 1 to 4 below are the same four cells.
#
# In each cell, Python works out the expression and shows the answer below the cell. You do not need `print()` here. A notebook, like the interactive shell, automatically shows the value of the **last line** of a cell.
#
# The four operators used here are:
#
# | Operator | Meaning | Example | Result |
# |---|---|---|---|
# | `+` | Addition | `2 + 4` | `6` |
# | `*` | Multiplication | `2 * 4` | `8` |
# | `**` | Power (raise to) | `2 ** 4` | `16` |
# | `/` | Division | `2 / 4` | `0.5` |
#
# Subtraction (`-`) works the same way. You can also use round brackets `( )` to group parts of an expression, just as in school maths.
#
# ### Example 1: Addition, and your first comment
#
# **What it does:** adds 2 and 4 and shows 6.
#
# **How it does it:**
#
# - Line 1 starts with `#`. Everything after a `#` up to the end of that line is a **comment**. Python skips it completely.
# - Line 2 is `2+4`. Python works out the sum. The part `# Addition` is again a comment, so Python ignores it.
# - Because `2+4` is the last line of the cell, the notebook shows its value.
#
# **Why:** comments let you leave notes for people who read your code. Python does not read them at all.
#
# **Learning points:**
#
# - A comment starts with `#` and runs to the end of the line.
# - A comment can take a full line (line 1) or sit at the end of a line of code (line 2).
# - In a notebook, the value of the last line is shown on its own.

# %%
# Note comments in Python begin with # (hash) and are ignored by the interpreter
2+4# Addition
# Out:
# 6

# %% [markdown]
# ### Example 2: Multiplication
#
# **What it does:** multiplies 2 by 4 and shows 8.
#
# **How:** Python uses `*` (the star, or asterisk) for multiplication. It does not use `x`, because `x` is a letter and can be a variable name.
#
# **Learning point:** the multiplication sign in Python is `*`.

# %%
2*4# Multiplication
# Out:
# 8

# %% [markdown]
# ### Example 3: Power
#
# **What it does:** works out 2 raised to the power 4, which is 2 x 2 x 2 x 2 = 16.
#
# **How:** two stars `**` mean "raise to the power of". The number on the left is the base. The number on the right is the power.
#
# **Learning point:** `**` is the power operator. Be careful: `2*4` is 8, but `2**4` is 16. One extra star changes the answer.

# %%
2**4# 2 raised to power 4
# Out:
# 16

# %% [markdown]
# ### Example 4: Division
#
# **What it does:** divides 2 by 4 and shows 0.5.
#
# **How:** a single slash `/` means division. In Python 3, `/` always gives a decimal answer (a **float**), even when both numbers are whole numbers.
#
# **Learning point:** the result of `/` is always a float.

# %%
2/4# 2 divided by 4
# Out:
# 0.5

# %% [markdown]
# ### Notes on Example 4 (and Examples 1 to 3)
#
# **1. Division in Python is not the same as in C.**
# In C or C++, dividing two whole numbers throws away the decimal part, so `2/4` gives `0`. Python 3 does not do this. It keeps the decimal part.
#
# | Expression | Result in Python 3 | Type of the result |
# |---|---|---|
# | `2/4` | `0.5` | float |
# | `4/2` | `2.0` | float (not `2`) |
# | `7//2` | `3` | int (`//` drops the decimal part) |
# | `7%2` | `1` | int (`%` gives the remainder) |
#
# You will meet `//` and `%` in the chapter on operators. Try them now if you like: add a new cell and type `7//2`.
#
# **2. Spaces in expressions.**
# `2+4# Addition` works, but it is a little squeezed. The Python style guide (PEP 8, see Example 14) suggests spaces around operators and two spaces before an end-of-line comment:
#
# ```python
# 2 + 4  # Addition
# ```
#
# Both versions give exactly the same result. Spacing only makes code easier to read.
#
# **3. Try it yourself.** Change the numbers in Examples 1 to 4 and run the cells again. Then try `(2 + 4) * 3` and `2 + 4 * 3`. Why are the answers different?

# %% [markdown]
# ## Section 1.9: Using the `print()` function
#
# ### Example 5: Printing text and a result together
#
# **What it does:** prints a piece of text followed by the answer to `2+2`:
#
# ```
# The result of 2 + 2 is:-> 4
# ```
#
# **How it does it:**
#
# - `print` is a built-in **function**. To call (use) a function, you write its name followed by round brackets `( )`.
# - Inside the brackets you give the things you want printed. These are called **arguments**. Here there are two, separated by a comma:
#   1. `"The result of 2 + 2 is:->"` is text inside double quotes. Text in quotes is called a **string**. It is printed exactly as it is.
#   2. `2+2` is not in quotes, so Python works it out first and gets `4`.
# - `print()` puts one space between its arguments and moves to a new line at the end.
#
# **Why:** in a script (a `.py` file), Python does not show values on its own the way a notebook does. `print()` is how a program shows results to the user.
#
# **Learning points:**
#
# - Anything inside quotes is printed as it is. `"2 + 2"` inside the string stays as the text `2 + 2`.
# - Anything outside quotes is worked out first. `2+2` becomes `4`.
# - Double quotes `" "` and single quotes `' '` both make strings.
# - Commas separate the arguments, and `print()` adds a space between them.
#
# ```mermaid
# flowchart TD
#     S1["1. Python reads the call to print"] --> S2["2. First argument is a string. It is kept as it is"]
#     S2 --> S3["3. Second argument is 2+2. Python works it out and gets 4"]
#     S3 --> S4["4. print joins the two values with one space"]
#     S4 --> S5["5. The line is shown and the cursor moves to a new line"]
# ```
#
# **Signature of `print()`** (the full list of what it accepts):
#
# ```python
# print(*objects, sep=' ', end='\n', file=None, flush=False)
# ```
#
# | Parameter | What it means | Default |
# |---|---|---|
# | `*objects` | Any number of values to print, separated by commas | nothing (prints an empty line) |
# | `sep` | What to put between the values | one space `' '` |
# | `end` | What to put after the last value | a new line `'\n'` |
# | `file` | Where to send the output | the screen |
# | `flush` | Send the output out at once | `False` |
#
# For now you only need `*objects`. The "Beyond the Book" section shows `sep` and `end`.

# %%
print("The result of 2 + 2 is:->", 2+2 )
# Out:
# The result of 2 + 2 is:-> 4

# %% [markdown]
# ## Section 1.10: Running Python from a file (a script)
#
# ### Example 6: The one-line script `hello.py`
#
# **What it does:** prints the message `Hello from a Python script!`.
#
# **How it is meant to be used:** in the book, this line is saved in a file named `hello.py`. The file is then run from a terminal (command prompt) by typing:
#
# ```
# python hello.py
# ```
#
# On some computers (mostly macOS and Linux) the command is `python3 hello.py`.
#
# Here, in the notebook, we simply run the line in a cell. The output is the same.
#
# **Why:** a script is saved. You can run it again tomorrow, share it with a friend, or make it longer. Lines typed in the interactive shell are lost when you close it.
#
# **Learning points:**
#
# - Any file whose name ends in `.py` is a Python script.
# - A script is run as a whole, from the first line to the last.
# - In a script, you must use `print()` to see anything. A script does not show values automatically.
#
# ```mermaid
# flowchart TD
#     S1["1. Create a file named hello.py"] --> S2["2. Type the print line into the file"]
#     S2 --> S3["3. Save the file"]
#     S3 --> S4["4. Open a terminal in the same folder"]
#     S4 --> S5["5. Type: python hello.py and press Enter"]
#     S5 --> S6["6. Python runs the file line by line"]
#     S6 --> S7["7. Output: Hello from a Python script!"]
# ```
#
# Want to create and run a real `hello.py` file inside Colab? See "Beyond the Book", Extra 1.

# %%
print("Hello from a Python script!")
# Out:
# Hello from a Python script!

# %% [markdown]
# ### Notes on Example 6
#
# **Why use a script?** Use a script when:
#
# - you want to keep your code,
# - the program is long,
# - you want to use functions, loops and modules,
# - someone else needs to run your program,
# - you want the computer to run it on its own, for example at a set time every day.
#
# **Shell or script: a quick comparison**
#
# | Feature | Python shell (command line) | Python script (.py file) |
# |---|---|---|
# | Saves your code | No | Yes |
# | Good for testing a line or two | Yes | Not ideal |
# | Suitable for full programs | No | Yes |
# | Can be run again later | No | Yes |

# %% [markdown]
# ## Section 1.11: Comments
#
# Python has two ways to write notes inside code:
#
# | | Hash `#` | Triple quotes `"""..."""` or `'''...'''` |
# |---|---|---|
# | What it really is | A true comment | A string (text value) |
# | What Python does with it | Skips it completely | Creates the string, then throws it away if it is not used |
# | Covers | From `#` to the end of that line | As many lines as you like |
# | Main use | Explaining *how* the code works, line by line | Docstrings: describing *what* a function, class or module does and how to use it |
# | Read by | People reading the code | People and tools that build documentation (like `help()`) |
#
# ### Example 7: A comment over two lines using `#`
#
# **What it does:** nothing that you can see. Both lines are comments, so Python skips them. The cell runs without any output.
#
# **How:** a `#` comment only covers one line. To write a note that goes over two lines, you put a `#` at the start of **each** line.
#
# **Why:** this is the normal way to write a longer note in Python code.
#
# **Learning points:**
#
# - Every comment line needs its own `#`.
# - If you forget the `#` on the second line, Python will try to run that text as code and you will get an error. Try it: delete the `#` at the start of line 2 and run the cell.

# %%
#This is a comment which extends over two lines..... this is line 1
#... This is line 2

# %% [markdown]
# ### Example 8: Triple quotes used as a multi-line comment
#
# **What it does:** creates a string that spans three lines.
#
# **How:** text that starts with three quote marks (`"""` or `'''`) and ends with the same three quote marks can run over many lines. This is called a **triple-quoted string**.
#
# **Why:** people often use triple quotes as a multi-line comment, because Python does nothing harmful with a string that is not stored or used.
#
# **Learning points:**
#
# - Triple quotes make a real string. They are not a true comment.
# - When a triple-quoted string is the first line inside a function, class or module, it becomes a **docstring**. Tools such as `help()` read docstrings to build documentation.
#
# Run the cell and then read the note below it. The output may surprise you.

# %%
""" Multi-line quote
... continues
.... ends"""
# Out:
# ' Multi-line quote\n... continues\n.... ends'

# %% [markdown]
# ### Notes on Example 8: why did the notebook show the text?
#
# A true comment (`#`) never produces output. But this cell **did** show something like:
#
# ```
# ' Multi-line quote\n... continues\n.... ends'
# ```
#
# The reason:
#
# 1. The triple-quoted text is a **string value**, just like `2+4` is a number value.
# 2. It is the last line of the cell. A notebook always shows the value of the last line.
# 3. So the notebook shows the string. The `\n` marks show where each new line starts inside the string.
#
# In a `.py` script, nothing would be shown, because a script does not show values on its own. That is why triple-quoted strings behave like comments inside scripts.
#
# ```mermaid
# flowchart TD
#     S1["1. Python reads a line"] --> S2{"2. Does the line start with a hash?"}
#     S2 -->|Yes| S3A["3A. It is a comment. Python skips it"]
#     S2 -->|No| S3B["3B. Python runs the line"]
#     S3B --> S4B{"4B. Is it a triple-quoted string on its own?"}
#     S4B -->|Yes| S5B["5B. A string is made and then thrown away. In a notebook, if it is the last line, it is shown"]
#     S4B -->|No| S6B["6B. Normal code runs"]
# ```
#
# **Remember:** use `#` for comments. Keep triple quotes for docstrings.

# %% [markdown]
# ## Section 1.11.1: Statements over many lines, and many statements on one line
#
# A **statement** is one instruction that Python can run. For example, `x = 10` is an assignment statement. `if`, `for` and `while` statements are other kinds.
#
# Normally, a statement ends where the line ends. The next four examples show how to bend this rule, and when you should not.
#
# | Way | How it looks | Needs a special character? | Recommended? |
# |---|---|---|---|
# | Explicit line continuation | End the line with a backslash `\` | Yes, `\` | Only when there is no better way |
# | Implicit line continuation | Keep the statement inside `( )`, `[ ]` or `{ }` | No | Yes, the preferred way |
# | Many statements on one line | Separate them with semicolons `;` | Yes, `;` | No, avoid it |
# | One statement per line | The normal way | No | Yes |
#
# ### Example 9: Explicit line continuation with a backslash
#
# **What it does:** works out `2 + 3 + 4` and shows `9`, even though the sum is split over two lines.
#
# **How it does it:**
#
# - The first three lines are comments. Python skips them.
# - Line 4 ends with a backslash `\`. This tells Python: "the statement is not finished, carry on to the next line."
# - Python joins line 4 and line 5 and reads them as `2 + 3 + 4`.
#
# **Why:** it lets you break a very long statement into shorter lines that fit on the screen.
#
# **Learning points:**
#
# - The backslash must be the **very last character** on the line. Nothing can come after it: not a comment, and not even a space. Otherwise Python raises `SyntaxError: unexpected character after line continuation character`.
# - This is why the comment is written on separate lines above the code, and not after the `\`.

# %%
# Backslash (\) indicates explicit line continuation
# But there should be nothing after \ else SyntaxError:
# unexpected character after line continuation character
2 + 3 \
+ 4
# Out:
# 9

# %% [markdown]
# ### Notes on Example 9
#
# ```mermaid
# flowchart TD
#     S1["1. Python reads line 4: 2 + 3 and a backslash"] --> S2{"2. Is the backslash the last character on the line?"}
#     S2 -->|Yes| S3A["3A. Python joins the next line: 2 + 3 + 4"]
#     S3A --> S4A["4A. Python works out the sum and shows 9"]
#     S2 -->|No, a space or comment follows| S3B["3B. SyntaxError. Nothing is run"]
# ```
#
# **Try it:** put a space after the backslash on line 4 and run the cell. Then put `# test` after the backslash. Read the error each time, then undo your change.
#
# ### Example 10: Implicit line continuation inside brackets
#
# **What it does:** adds `10 + 20 + 30 + 40` and prints `100`.
#
# **How it does it:**
#
# 1. Line 1 opens a round bracket `(`.
# 2. As long as a bracket is open, Python knows the statement is not finished. It keeps reading the next lines.
# 3. At the closing bracket `)` on line 4, the statement is complete. Python adds the numbers and stores `100` in `result`.
# 4. Line 5 prints `result`.
#
# **Why:** this is the clean, preferred way to split a long line. You do not need a backslash, and a stray space at the end of a line cannot break it.
#
# **Learning points:**
#
# - An open `(`, `[` or `{` lets a statement continue over many lines.
# - Python waits for the matching closing bracket before it treats the statement as complete.
# - The indentation of lines 2 and 3 is only for looks. Inside brackets, Python does not care about it.

# %%
result = (
    10 + 20 +
    30 + 40
)
print(result)
# Out:
# 100

# %% [markdown]
# ### Example 11: Many statements on one line with semicolons
#
# **What it does:** stores 5 in `a`, stores 6 in `b`, and prints their sum `11`. All three steps are on one line.
#
# **How it does it:** a semicolon `;` separates statements. Python runs them one after the other, from left to right:
#
# 1. `a = 5` puts the value 5 in the variable `a`.
# 2. `b = 6` puts the value 6 in the variable `b`.
# 3. `print(a + b)` adds them and prints `11`.
#
# **Why it is shown:** so that you can recognise it when you see it. It is allowed, but it is **not** good practice.
#
# **Learning point:** a semicolon lets you put several statements on one line. Avoid it, because:
#
# - the code is harder to read,
# - errors are harder to find, since one line now holds several steps,
# - the logic is hidden, and mistakes are easier to miss.

# %%
a = 5; b = 6; print(a + b)
# Out:
# 11

# %% [markdown]
# ### Example 12: The better version, one statement per line
#
# **What it does:** the same work as Example 11, and prints `11`.
#
# **How:** each statement is on its own line. No semicolons are needed.
#
# **Why:** the Python style guide (PEP 8) recommends one statement per line. Each line does one job, so the code is easy to read and to fix.
#
# **Learning point:** Examples 11 and 12 give the same result. The difference is only readability, and readability matters a lot when you or someone else comes back to the code later.

# %%
a = 5
b = 6
print(a + b)
# Out:
# 11

# %% [markdown]
# ## Section 1.12: Indentation (no code in the book)
#
# Most languages such as C, C++ and Java use braces `{ }` to mark a block of code. Python uses **indentation** instead: the spaces at the start of a line.
#
# - A block (for example, the body of an `if` or a function) starts when lines are indented.
# - The block ends at the first line that goes back to the earlier indentation.
# - Use **4 spaces** per level. This is the common style.
# - Do not mix tabs and spaces. It can cause errors or strange behaviour.
#
# You can see indentation at work in Example 14 below, inside the functions, classes and `if` statements.

# %% [markdown]
# ## Section 1.13: Python keywords
#
# **Keywords** are words that Python keeps for itself. Each one has a fixed meaning in the grammar of the language. You cannot use a keyword as the name of a variable, a function, a class, or anything else you create.
#
# Keywords are **case-sensitive**. `True` is a keyword, but `true` is not. `if` is a keyword, but `If` is not.
#
# ### Example 13: Printing the list of all keywords
#
# **What it does:** prints every keyword of the Python version you are using.
#
# **How it does it:**
#
# 1. `import keyword` loads a small module (a ready-made file of Python code) named `keyword`. It comes with Python, so you do not need to install it.
# 2. Inside that module there is a list named `kwlist` that holds all the keywords.
# 3. `print(keyword.kwlist)` prints that list. The dot in `keyword.kwlist` means "the `kwlist` that lives inside `keyword`".
#
# **Why:** you do not need to learn the list by heart. You can always ask Python for it. The list can change a little between Python versions, and this code always gives the correct list for your version.
#
# **Learning points:**
#
# - `import` gives you access to a module.
# - A dot (`.`) is used to reach something inside a module.
# - `kwlist` is a list, not a function, so there are no brackets after it.
#
# **What is inside the `keyword` module:**
#
# | Name | Kind | What it gives you |
# |---|---|---|
# | `keyword.kwlist` | list | All keywords of your Python version |
# | `keyword.iskeyword(s)` | function | `True` if the text `s` is a keyword, otherwise `False` |
# | `keyword.softkwlist` | list | "Soft" keywords (see Beyond the Book, Extra 3) |
#
# ```mermaid
# flowchart TD
#     S1["1. import keyword: load the keyword module"] --> S2["2. keyword.kwlist: reach the list stored in the module"]
#     S2 --> S3["3. print: show the list on the screen"]
# ```

# %%
# To see list of all keywords in Python type the following two commands
import keyword     # FIRST Command. Imports module keyword
print(keyword.kwlist)     # SECOND Command
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### Notes on Example 13
#
# **1. Your output may differ a little from the book.** The list depends on the Python version. Python 3.10 and later versions have 35 keywords. To see which version you are using, run `import sys` and then `print(sys.version)` in a new cell. For example, Python 3.9 also showed a special entry named `__peg_parser__`. It was removed in Python 3.10, so you will not see it in Colab.
#
# **2. `print` and `exec` are not keywords in Python 3.** They were keywords in the old Python 2. In Python 3 they are built-in **functions**. That is why you call them with brackets, like `print("Hi")`, and why they do not appear in the list above.
#
# **3. The 35 keywords grouped by what they do.** You do not need to learn these now. You will meet each group in later chapters.
#
# | Group | Keywords |
# |---|---|
# | Special values | `True`, `False`, `None` |
# | Logic and testing | `and`, `or`, `not`, `is`, `in` |
# | Making decisions | `if`, `elif`, `else` |
# | Loops | `for`, `while`, `break`, `continue` |
# | Functions | `def`, `return`, `lambda`, `yield` |
# | Classes | `class` |
# | Using modules | `import`, `from`, `as` |
# | Handling errors | `try`, `except`, `finally`, `raise`, `assert` |
# | Managing resources | `with` |
# | Scope of names | `global`, `nonlocal` |
# | Running tasks side by side | `async`, `await` |
# | Other | `pass`, `del` |
#
# Notice that only `True`, `False` and `None` start with a capital letter.

# %% [markdown]
# ## Sections 1.14 and 1.15: Identifiers, naming conventions and PEP 8
#
# An **identifier** is a name you give to something in your code: a variable, a function, a class, a module and so on.
#
# There are two kinds of naming rules:
#
# 1. **Legal rules.** Python checks these. Break one and your code will not run.
# 2. **Conventions.** Python does not check these. They are good habits that most Python programmers follow, mostly taken from PEP 8. Your code will run if you ignore them, but it will be harder for others to read.
#
# ### The legal rules
#
# | Rule | What it means | Valid examples | Invalid examples |
# |---|---|---|---|
# | 1. Allowed characters | Only letters (a-z, A-Z), digits (0-9) and the underscore `_` | `total_marks`, `value2`, `Student_Name` | `hello-world`, `age@school` |
# | 2. First character | Must be a letter or an underscore, never a digit | `value1`, `_count`, `name2` | `1value`, `2ndNumber` |
# | 3. No keywords | A keyword cannot be used as a name | (none) | `for`, `while`, `class`, `break` |
# | 4. No special symbols | Symbols like `@`, `$`, `!`, `#`, `%` and `-` are not allowed | (none) | `first-name`, `price$`, `value#1` |
# | 5. Case matters | Names that differ only in capital letters are different names | `student`, `Student`, `STUDENT` are three separate names | (none) |
#
# A word of care about `print`: it is not a keyword in Python 3, so `print = 10` is legal. But it is a very bad idea. After that line, `print` means 10, and `print("Hi")` stops working until you restart the notebook. The same goes for other built-in names such as `list`, `str`, `type` and `id`.
#
# ```mermaid
# flowchart TD
#     S1["1. Take the name you want to use"] --> S2{"2. Does it start with a letter or an underscore?"}
#     S2 -->|No| X["Not a valid name"]
#     S2 -->|Yes| S3{"3. Are all the other characters letters, digits or underscores?"}
#     S3 -->|No| X
#     S3 -->|Yes| S4{"4. Is it a keyword?"}
#     S4 -->|Yes| X
#     S4 -->|No| S5["5. Valid name. You can use it"]
# ```
#
# ### PEP and PEP 8
#
# - **PEP** stands for **Python Enhancement Proposal**. A PEP is a document that proposes or describes something about Python.
# - **PEP 8** is the official **style guide** for Python code. It covers naming, spacing, line length and more.
#
# The main naming conventions from PEP 8:
#
# | What you are naming | Style | Example | Avoid |
# |---|---|---|---|
# | Variables | snake_case: lowercase words joined by underscores | `student_age` | `StudentAge`, `studentage` |
# | Functions | snake_case | `calculate_average` | `CalculateAverage` |
# | Constants (values that should not change) | UPPER_CASE with underscores | `MAX_LIMIT` | `maxlimit` |
# | Classes | PascalCase: each word starts with a capital, no underscores | `StudentRecord` | `studentRecord`, `Attendance_Manager` |
# | Names meant for use only inside a module | A single leading underscore | `_internal_utility_function` | (no underscore, if it is meant to be internal) |
#
# About camelCase: in camelCase the first word is lowercase and each later word starts with a capital, as in `myAge`. The capital letter looks like the hump of a camel. camelCase is common in Java and JavaScript. PEP 8 prefers snake_case (`my_age`) for variables and functions in Python.
#
# Also choose names that tell you what they hold. `n = 10` is legal, but `number_of_students = 10` explains itself.
#
# ### Example 14: PEP 8 style versus non-PEP 8 style
#
# This script is not printed in the book. It supports Sections 1.14 and 1.15, where the book points to the online resource for more on PEP 8.
#
# **What it does:** shows, side by side, the right way (PEP 8) and the way to avoid (non-PEP 8) for five kinds of code. It prints one line for each section.
#
# **How it does it:** the script has five parts. Each part has a "PEP 8 STYLE (CORRECT)" block and a "NON-PEP 8 STYLE (AVOID)" block.
#
# | Part | Topic | The PEP 8 way | The way to avoid |
# |---|---|---|---|
# | 1 | Variables and constants | `student_age`, `MAX_LIMIT` | `StudentAge`, `totalScore`, `maxlimit` |
# | 2 | Functions | `def calculate_average(...)` with the body on its own indented lines | `CalculateAverage`, with the whole body squeezed onto the `def` line with semicolons |
# | 3 | Classes | `StudentRecord`, `AttendanceManager` | `studentRecord`, `Attendance_Manager` |
# | 4 | `if` statements | Spaces around `>` and `==`, body on its own indented line | `if x>5: print("x>5")` on one line |
# | 5 | Internal names | `_internal_utility_function` with a leading underscore | (not shown) |
#
# **Why:** code is read far more often than it is written. When everyone follows the same style, anyone can pick up anyone's code and read it quickly.
#
# **Learning points:**
#
# - **Both styles run.** Python does not check style. The "AVOID" code runs without any error. You can even see its output: the line `x>5` is printed by the squeezed `if` statement.
# - PEP 8 is about **readability**, not about whether code works.
# - Some things in the script, such as functions, classes and `if`, are covered in later chapters. For now, just look at how the names are written and how the code is spaced out.
# - `pass` is a keyword that means "do nothing". It is used here because a class body cannot be empty.
#
# ```mermaid
# flowchart TD
#     S1["1. Variables: create student_age, total_score, MAX_LIMIT and the badly named versions. Print a message"] --> S2["2. Functions: define calculate_average and CalculateAverage. Call calculate_average with 80, 90, 100 and print 90.0"]
#     S2 --> S3["3. Classes: define StudentRecord, AttendanceManager and the badly named versions. Print a message"]
#     S3 --> S4["4. Conditionals: set x to 10. The PEP 8 if prints: x is greater than 5. The squeezed if prints: x>5"]
#     S4 --> S5["5. Internal names: call _internal_utility_function and print what it returns"]
# ```

# %%
# ===============================================================
# PYTHON STYLE GUIDE: PEP 8 VS. NON-PEP 8
# This script demonstrates the "Pythonic" way to write code.
# ===============================================================

# ---------------------------------------------------------------
# 1. VARIABLES: The "Identity" of your data
# Rule: Use snake_case (all lowercase with underscores)
# ---------------------------------------------------------------

# PEP 8 STYLE (CORRECT)
# This is easy to read because words are separated by underscores.
student_age = 20
total_score = 95

# CONSTANTS: Use all UPPERCASE to show this value should not change.
MAX_LIMIT = 100

# NON-PEP 8 STYLE (AVOID)
StudentAge = 20  # Avoid starting variables with Capital Letters
totalScore = 95  # This is "camelCase" - common in Java, but not Python
maxlimit = 100    # Hard to read; always use underscores to separate words

print("Section 1: Variable naming conventions demonstrated.")


# ---------------------------------------------------------------
# 2. FUNCTIONS: Actions your code performs
# Rule: Use snake_case and keep it readable
# ---------------------------------------------------------------

# PEP 8 STYLE (CORRECT)
# Use descriptive names and give the code space to "breathe."
def calculate_average(score1, score2, score3):
    total = score1 + score2 + score3
    return total / 3

# NON-PEP 8 STYLE (AVOID)
# Never put the logic on the same line as the 'def' statement.
def CalculateAverage(score1,score2,score3): total=score1+score2+score3;return total/3

print(f"Section 2: Average is {calculate_average(80, 90, 100)}")


# ---------------------------------------------------------------
# 3. CLASSES: Blueprints for objects
# Rule: Use PascalCase (Capitalize every word, no underscores)
# ---------------------------------------------------------------

# PEP 8 STYLE (CORRECT)
class StudentRecord:
    """Classes represent 'Things' so we capitalize them."""
    pass

class AttendanceManager:
    pass

# NON-PEP 8 STYLE (AVOID)
class studentRecord: # Should be Capitalized
    pass

class Attendance_Manager: # Avoid underscores in class names
    pass

print("Section 3: Class naming (PascalCase) demonstrated.")


# ---------------------------------------------------------------
# 4. CONDITIONALS: Decision making
# Rule: Use spaces around operators and proper indentation
# ---------------------------------------------------------------

x = 10

# PEP 8 STYLE (CORRECT)
# Space around the '>' and the '==' makes it much cleaner.
if x > 5:
    print("Section 4: x is greater than 5")
elif x == 5:
    print("Section 4: x is exactly 5")

# NON-PEP 8 STYLE (AVOID)
# Don't squash code together; it makes debugging very difficult.
if x>5: print("x>5")


# ---------------------------------------------------------------
# 5. INTERNAL NAMES (Advanced)
# Rule: Start with a single underscore for internal/private use
# ---------------------------------------------------------------

# PEP 8 STYLE (CORRECT)
# This tells other programmers: "Use this only inside this script."
def _internal_utility_function():
    return "This is a hidden helper function."

print(f"Section 5: {_internal_utility_function()}")

# ===============================================================
# END OF SCRIPT: All code is PEP 8 compliant and runs perfectly!
# ===============================================================
# Out:
# Section 1: Variable naming conventions demonstrated.
# Section 2: Average is 90.0
# Section 3: Class naming (PascalCase) demonstrated.
# Section 4: x is greater than 5
# x>5
# Section 5: This is a hidden helper function.

# %% [markdown]
# ### Notes on Example 14
#
# **1. Reading the output line by line**
#
# | Output line | Printed by |
# |---|---|
# | `Section 1: Variable naming conventions demonstrated.` | The `print()` at the end of part 1 |
# | `Section 2: Average is 90.0` | `calculate_average(80, 90, 100)` works out (80 + 90 + 100) / 3 = 90.0. It is a float because `/` always gives a float |
# | `Section 3: Class naming (PascalCase) demonstrated.` | The `print()` at the end of part 3 |
# | `Section 4: x is greater than 5` | The PEP 8 `if` statement, because x is 10 |
# | `x>5` | The squeezed, non-PEP 8 `if` statement. It runs fine, it is just hard to read |
# | `Section 5: This is a hidden helper function.` | The value returned by `_internal_utility_function()` |
#
# **2. Why is there no output from `CalculateAverage`?** It is defined, but never called. A function only runs when it is called.
#
# **3. About the last comment in the script.** The closing comment says that all the code is PEP 8 compliant. Read it as "all the code runs without errors". The "AVOID" blocks are left in on purpose to show bad style, so they are not PEP 8 compliant.
#
# **4. The `f` before some strings.** In `f"Section 2: Average is {calculate_average(80, 90, 100)}"`, the `f` makes an **f-string**. The part inside the curly braces `{ }` is worked out and its value is put into the text. You will learn f-strings properly in the chapter on strings.
#
# **5. A tip.** Tools called "linters" (for example `flake8` or `pylint`) and formatters (for example `black`) can check or fix PEP 8 style for you. VS Code can run them as you type.

# %% [markdown]
# ## Section 1.16: Variables, literals, references and built-in types
#
# Some ideas in this part may feel new if you have never programmed before. Do not worry. Run each example, look at the output, and they will become clear.
#
# ### A variable is a tag, not a box
#
# A **variable** is a name that refers to a value (an **object**) stored in memory. The way this works is different in C++ and Python.
#
# - **In C++,** a variable is like a **box**. Each box is made for one kind of thing, just as a shoe box is made for shoes and a match box for matches. You must say what kind of box it is (`int`, `float` and so on) before you use it, and it keeps that kind for life.
# - **In Python,** a variable is like a **price tag**. The tag has no type of its own. You can take it off a shoe and tie it to a book. The **object** the tag is tied to has the type.
#
# | Feature | C++ (statically typed) | Python (dynamically typed) |
# |---|---|---|
# | What a variable is | A box that holds a value | A tag (label) tied to a value |
# | Must you declare the type? | Yes (`int`, `float`, `string` ...) | No |
# | Who has the type? | The box (the variable) | The object (the value) |
# | Can the same name later refer to a different type? | No. An `int` variable cannot later hold a string | Yes. The same name can point to any type |
# | Everyday picture | Boxes for shoes, boxes for matches | A price tag that can be tied to any item |
#
# **Static and dynamic typing.** C++ is called **statically typed**, because the type of each variable is fixed when you write the code. Python is **dynamically typed**, because Python works out the type from the object at the moment the code runs.
#
# **Python is also strongly typed.** Dynamic does not mean careless. Python will not quietly mix types that do not fit together. For example, `"5" + 5` gives an error instead of guessing what you meant. (See Beyond the Book, Extra 4.)
#
# ### Example 15: Two tags on one object, then one tag moves
#
# **What it does:** prints `2` and then `3`.
#
# **How it does it, step by step:**
#
# 1. `x = 2`: Python creates the object `2` and ties the tag `x` to it.
# 2. `y = x`: Python does **not** copy the number. It ties a second tag, `y`, to the **same** object `2`.
# 3. `y = 3`: Python creates the object `3` and moves the tag `y` to it. Tag `x` is not touched. It is still on `2`.
# 4. `print(x)` prints `2`, and `print(y)` prints `3`.
#
# **Why:** many beginners expect `x` to change to 3 as well. It does not, because `y = 3` only moves the tag `y`.
#
# **Learning points:**
#
# - `=` means "tie this name to that object". It does not mean "equal" as in maths.
# - `y = x` makes both names refer to the same object. It does not create a copy.
# - Giving a new value to one name never changes another name.
#
# ```mermaid
# flowchart TD
#     S1["1. x = 2: object 2 is created. Tag x is tied to it"] --> S2["2. y = x: tag y is tied to the same object 2. Now x and y both point to 2"]
#     S2 --> S3["3. y = 3: object 3 is created. Tag y moves to 3. Tag x stays on 2"]
#     S3 --> S4["4. print x shows 2. print y shows 3"]
# ```

# %%
x = 2  # x "points" to 2
y = x  # Now y also "points" to 2
y = 3  # Now y "points" to 3
print(x)  # x still "points" to 2, so it prints 2
print(y)  # y now "points" to 3, so it prints 3
# Out:
# 2
# 3

# %% [markdown]
# ### Example 16: The same name, two different types
#
# **What it does:** prints the type of `x` twice. First it is a string (`str`), then a whole number (`int`).
#
# **How it does it:**
#
# 1. `x = 'abc'` ties the tag `x` to the string `'abc'`.
# 2. `type(x)` asks: "what type is the object that `x` points to?" The answer is `<class 'str'>`.
# 3. `x=5` moves the tag `x` to the integer `5`. The string `'abc'` is left without a tag.
# 4. `type(x)` now answers `<class 'int'>`.
#
# **Why:** this is dynamic typing in action. You never told Python the type. It looked at the object each time and worked it out.
#
# **Learning points:**
#
# - `type()` reports the type of the **object**, not of the name.
# - The same name can point to objects of different types at different times.
# - In Python every type is a **class**, which is why the output says `class`.
#
# **Signature of `type()`** (the one-argument form used here):
#
# ```python
# type(object)
# ```
#
# | Part | Meaning |
# |---|---|
# | `object` | Any value or variable |
# | Returns | The type (class) of that object, for example `<class 'int'>` |

# %%
# type() function is used to get type of an object
x = 'abc'
print(type(x))    # <class'str'>
x=5
print(type(x)) # <class'int'>
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ### Notes on Example 16
#
# Python shows a space after `class`: the real output is `<class 'str'>` and `<class 'int'>`.
#
# Also, `x=5` has no spaces around `=`. It works the same as `x = 5`, but PEP 8 prefers the spaced version.
#
# Some common types you will meet soon:
#
# | Example value | `type()` shows | Name of the type |
# |---|---|---|
# | `5` | `<class 'int'>` | integer (whole number) |
# | `78.11` | `<class 'float'>` | floating-point (decimal) number |
# | `'abc'` | `<class 'str'>` | string (text) |
# | `True` | `<class 'bool'>` | Boolean (True or False) |
# | `None` | `<class 'NoneType'>` | the "no value" value |

# %% [markdown]
# ### Example 17: Casting a float to an int
#
# **Casting** (or **type conversion**) means making a new object of one type from an object of another type.
#
# **What it does:** turns the float `78.11` into the whole number `78`, and prints the **id** (identity number) of each object.
#
# **How it does it:**
#
# 1. `my_float = 78.11` creates a float object and ties the tag `my_float` to it.
# 2. `id(my_float)` gives the identity number of that float object.
# 3. `int(my_float)` builds a **new** integer object from it. The decimal part `.11` is dropped. The tag `my_int` is tied to this new object `78`.
# 4. `print(my_int)` prints `78`.
# 5. `id(my_int)` gives the identity of the integer object. It is a different number from step 2, because it is a different object.
# 6. `id(78)` gives the same number as `id(my_int)`. This shows that `my_int` points to the object `78`.
#
# **Why:** in Python it is the **object** that is converted, not the name. `int()` does not change the float. It makes a new integer, and the float stays as it was. Numbers cannot be changed in place (they are **immutable**), so converting always creates a new object.
#
# **Learning points:**
#
# - `int()` drops the decimal part. It does not round: `int(78.99)` is also `78`.
# - The original object (`78.11`) stays unchanged. Check it by printing `my_float` after the conversion.
# - The comments in the code mention `myInt`. They mean the variable `my_int`.
#
# **Signature of `int()`:**
#
# ```python
# int(x=0)
# int(x, base=10)
# ```
#
# | Parameter | Meaning |
# |---|---|
# | `x` | The value to convert, for example a float such as `78.11` or a string such as `"78"` |
# | `base` | Only used when `x` is a string. The number base, for example 2 for binary. Default is 10 |
# | Returns | A new `int` object. `int()` with nothing inside gives `0` |
#
# ```mermaid
# flowchart TD
#     S1["1. my_float = 78.11: a float object is created. Tag my_float points to it"] --> S2["2. id of my_float is printed"]
#     S2 --> S3["3. int of my_float makes a NEW int object 78. Tag my_int points to it"]
#     S3 --> S4["4. print my_int shows 78"]
#     S4 --> S5["5. id of my_int is printed. It differs from step 2"]
#     S5 --> S6["6. id of 78 is printed. It is the same as step 5"]
# ```

# %%
my_float = 78.11
print('id of my_float->',id(my_float)) # 1945253350608
my_int = int(my_float)    # int() is a casting function
print(my_int) # myInt will now point to value 78
print('id of my_int->', id(my_int)) # 1945171874576
print(id(78)) # Note id(78) is 1945171874576, same as id(myInt)
# Out:
# id of my_float-> 139644409729552
# 78
# id of my_int-> 22524680
# 22524680

# %% [markdown]
# ### Notes on Example 17
#
# **1. Your id numbers will be different.** The long numbers in the comments are the ones the author got. An id depends on where the object sits in memory on that computer at that moment. Your numbers will be different, and they change each time the notebook is restarted. What matters is the pattern:
#
# - `id(my_float)` is different from `id(my_int)`: two different objects.
# - `id(my_int)` is the same as `id(78)`: one and the same object.
#
# **2. Why are `id(my_int)` and `id(78)` the same?** The standard version of Python (called CPython) keeps one ready-made object for each small whole number from -5 to 256. Every time you use `78`, you get that same object. This saves memory. It is a hidden detail of CPython. Your programs should not depend on it.
#
# **3. Try it:** add `print(my_float)` at the end of the cell. It still prints `78.11`, which proves the original float was not changed.

# %% [markdown]
# ### Section 1.16.3: What happens in an assignment
#
# When you write `x = 3`, Python does three things:
#
# 1. It creates the object `3` (an `int`) in memory.
# 2. It creates the name `x`, if it does not exist yet. The name has no type of its own.
# 3. It ties the name `x` to the object `3`. This link is called a **reference**.
#
# If you now ask `type(x)`, you get `int`. That is the type of the object `x` refers to, not a type of `x` itself.
#
# ### Example 18: A simple assignment
#
# **What it does:** ties the name `x` to the integer `3`. There is no output, because there is no `print()` and an assignment has no value to show.
#
# **Learning point:** an assignment creates a reference from a name to an object.
#
# ```mermaid
# flowchart LR
#     S1["1. Object 3 is created in memory"] --> S2["2. Name x is created"] --> S3["3. Name x is tied to object 3"]
# ```

# %%
x = 3

# %% [markdown]
# ### Section 1.16.4: Shared references
#
# When two or more names point to the same object, the object has a **shared reference**.
#
# ### Example 19: Two names, one object
#
# **What it does:** makes `x` and `y` point to the same object. There is no output.
#
# **How it does it:**
#
# 1. `x = 3`: tag `x` is tied to the object `3`.
# 2. `y = 2`: tag `y` is tied to the object `2`.
# 3. `y = x`: tag `y` is moved to whatever `x` points to, which is the object `3`.
#
# After line 3, **both `x` and `y` refer to the object 3**. The object `3` now has a shared reference.
#
# The object `2` has no tag left. Python notices this and frees that memory on its own. This is the **automatic memory management** (garbage collection) described in Section 1.3.2.
#
# **Learning point:** `y = x` makes `y` point to the object that `x` points to, here `3`.
#
# ```mermaid
# flowchart TD
#     S1["1. x = 3: tag x is tied to object 3"] --> S2["2. y = 2: tag y is tied to object 2"]
#     S2 --> S3["3. y = x: tag y moves to object 3. Both x and y now point to 3"]
#     S3 --> S4["4. Object 2 has no tag left. Python frees its memory automatically"]
# ```

# %%
x = 3
y = 2
y = x

# %% [markdown]
# ### Example 20: Changing one name does not change the other
#
# **Run Example 19 first.** This cell needs `x` and `y` from it.
#
# **What it does:** adds 2 to `x` and prints `5` and `3`.
#
# **How it does it:**
#
# 1. Before this cell, `x` and `y` both point to `3`.
# 2. `x = x + 2`: Python first works out the right-hand side. It reads the value of `x` (3), adds 2, and creates a **new** object `5`.
# 3. The tag `x` is moved to the new object `5`.
# 4. The tag `y` is not touched. It still points to `3`.
# 5. So `print(x)` shows `5`, and `print(y)` shows `3`.
#
# **Why:** the object `3` is not changed into `5`. Whole numbers cannot be changed in place (they are **immutable**). Python makes a new object and moves only the tag `x`. That is why `y` does not change.
#
# **Learning points:**
#
# - In `x = x + 2`, the right-hand side is worked out first, using the old value of `x`.
# - Changing what one name points to does not affect the other names.
# - Mutable objects (like lists) can behave differently with shared references. You will see this in the chapter on lists.
#
# ```mermaid
# flowchart TD
#     S1["1. Start: x and y both point to object 3"] --> S2["2. Work out x + 2: read 3, add 2, create new object 5"]
#     S2 --> S3["3. Move tag x to object 5"]
#     S3 --> S4["4. Tag y still points to object 3"]
#     S4 --> S5["5. Output: 5 and then 3"]
# ```

# %%
x = x + 2
print(x) # 5
print(y) # 3
# Out:
# 5
# 3

# %% [markdown]
# ## Section 1.16.5: Variable versus identifier
#
# People often use the words "variable" and "identifier" as if they meant the same thing. They do not.
#
# - An **identifier** is just a **name**.
# - A **variable** is a name that is tied to a value. So it has a name, a value, the type of that value, and a **scope** (the part of the program where the name can be used).
#
# | | Identifier | Variable |
# |---|---|---|
# | What it is | A name only | A name plus a value (with its type) plus a scope |
# | Can name | Variables, functions, classes, modules and more | Data only |
# | Example | `calculate_average` (a function name), `StudentRecord` (a class name), `age` | `age = 10` |
#
# So every variable has an identifier, but not every identifier is a variable.
#
# A variable must be **defined** (given a value) before you use it. If you use a name that has never been given a value, Python stops with a `NameError`. Example 21 shows this.
#
# ### Helper cell (not from the book)
#
# In this notebook, `x` was already given a value in Examples 15 to 20. So if you ran `x` now, you would see `5`, not an error. The cell below removes the name `x`, so that Example 21 behaves as it does in the book.
#
# - `x = None` makes sure `x` exists. This way the next line works even if you skipped the earlier cells.
# - `del x` deletes the name `x`. (`del` is one of the keywords from Example 13.)

# %%
x = None  # make sure the name x exists
del x     # now remove the name x completely

# %% [markdown]
# ### Example 21: Using a name that has no value (this cell gives an error on purpose)
#
# **What it does:** tries to show the value of `x`. Since `x` does not exist, Python stops and reports a `NameError`.
#
# **How:** Python looks up the name `x`. It cannot find it, so it cannot go on.
#
# **Why:** this is one of the most common errors for beginners. It usually means a spelling mistake, or a cell that was not run yet.
#
# **Learning points:**
#
# - You must give a name a value before you use it.
# - The last line of the error message is the most useful part: `NameError: name 'x' is not defined`.
# - In the book, the error comes from a script file, so the message names the file (`c:\test11\ch1.py`). In Colab, the message names the notebook cell instead. The last line is the same.
#
# ```mermaid
# flowchart TD
#     S1["1. Python meets the name x"] --> S2{"2. Is x tied to an object?"}
#     S2 -->|Yes| S3A["3A. Python uses that object"]
#     S2 -->|No| S3B["3B. Python stops with NameError: name x is not defined"]
# ```

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined

# %% [markdown]
# ### Notes on Example 21
#
# If you used **Runtime > Run all**, the notebook stopped here. That is expected. Click the next code cell and choose **Runtime > Run after** to run the rest.
#
# How to fix a `NameError`:
#
# 1. Check the spelling. `Age` and `age` are different names.
# 2. Make sure the cell that creates the name has been run.
# 3. Make sure the name is given a value **before** the line that uses it.

# %% [markdown]
# ### Example 22: Looking at an object's identity with `id()`
#
# Every object in Python has three things:
#
# | Property | What it is | How to see it |
# |---|---|---|
# | Identity | A number that is unique to the object while it exists | `id(obj)` |
# | Type | The kind of object, such as `int` or `str` | `type(obj)` |
# | Value | The data it holds, such as `10` | `print(obj)` |
#
# A **name** has one more property: its **scope**, meaning where in the program the name can be used. You will learn about scope in the chapter on functions.
#
# **What the code does:** prints the id of the object `10`, then ties the name `age` to `10` and prints its id. Both ids are the same.
#
# **How it does it:**
#
# 1. `id(10)` works out the id of `10`, but the result is not printed. This is not the last line of the cell, so the notebook does not show it.
# 2. `print(id(10))` prints the id of the object `10`.
# 3. `age = 10` ties the tag `age` to the object `10`.
# 4. `print(id(age))` prints the id of the object that `age` points to. It is the same number as in step 2.
#
# **Why:** this shows that a variable is only a label for an object. `age` has no id of its own. `id(age)` gives the id of the object that `age` refers to.
#
# **Learning points:**
#
# - `id()` gives the identity of an **object**. In standard Python (CPython), this number is the object's address in memory.
# - If two names give the same id, they refer to the same object.
# - The same id here also comes from the small-number store described in the notes on Example 17: CPython keeps one shared object for each whole number from -5 to 256.
# - Your id numbers will not match the numbers in the comments. That is normal.
#
# **Signature of `id()`:**
#
# ```python
# id(object)
# ```
#
# | Part | Meaning |
# |---|---|
# | `object` | Any value or variable |
# | Returns | An integer. It is unique for that object as long as the object exists |
#
# ```mermaid
# flowchart TD
#     S1["1. id of 10 is worked out but not shown"] --> S2["2. print shows the id of object 10"]
#     S2 --> S3["3. age = 10: tag age is tied to the same object 10"]
#     S3 --> S4["4. print shows the id of the object age points to"]
#     S4 --> S5["5. The ids from step 2 and step 4 match: one object, two ways to reach it"]
# ```

# %%
id(10)
print(id(10))  # 2640531581520
age = 10
print(id(age))  # 2640531581520
# Out:
# 22522504
# 22522504

# %% [markdown]
# ## Chapter 1 in one table
#
# | Idea | Remember this |
# |---|---|
# | Python is interpreted | Code runs a little at a time. There is no separate compile step for you to do |
# | Interactive mode and script mode | Try ideas in the shell or a notebook. Keep programs in `.py` files |
# | Comments | `#` for comments. Triple quotes for docstrings |
# | Long statements | Prefer brackets `( )` over the backslash `\` |
# | Semicolons | Allowed, but avoid them. Write one statement per line |
# | Keywords | Reserved words. Use `keyword.kwlist` to see them |
# | Identifiers | Letters, digits and `_`. Must not start with a digit. Must not be a keyword |
# | PEP 8 | snake_case for variables and functions, PascalCase for classes, UPPER_CASE for constants |
# | Variables | A variable is a tag tied to an object. The object has the type, not the tag |
# | Assignment `=` | Ties a name to an object. It does not copy the object |
# | `type()` and `id()` | Show the type and the identity of the object a name refers to |

# %% [markdown]
# # Beyond the Book
#
# These four short extras build on ideas from this chapter. They are optional. Come back to them after you have worked through the examples above.
#
# ### Extra 1: Create and run a real script file inside Colab
#
# In Example 6 we ran the `print()` line directly. Here we will do what the book describes: save the line in a file named `hello.py`, and then run that file.
#
# **How it works:**
#
# - The first cell starts with `%%writefile hello.py`. This is a special notebook command, not Python. It saves the rest of the cell into a file named `hello.py`, instead of running it.
# - The second cell starts with `!`. In a notebook, `!` sends the rest of the line to the computer's terminal. So `!python hello.py` runs the file exactly as you would in a terminal.
#
# To see the file, click the folder icon on the left side of Colab. Note that files in Colab are deleted when the session ends.

# %%
# %%writefile hello.py
print("Hello from a Python script!")
# Out:
# Writing hello.py

# %%
# !python hello.py
# Out:
# Hello from a Python script!

# %% [markdown]
# ### Extra 2: The `sep` and `end` options of `print()`
#
# The signature of `print()` (see Example 5) has two useful options:
#
# - `sep` sets what goes **between** the values. The default is one space.
# - `end` sets what goes **after** the last value. The default is a new line.
#
# The cell below shows both. Compare each output line with the code that made it.

# %%
print("2 + 2", 4, sep=" = ")
print("A", "B", "C", sep="-")
print("This line does not end with a new line.", end=" ")
print("So this text continues on the same line.")
# Out:
# 2 + 2 = 4
# A-B-C
# This line does not end with a new line. So this text continues on the same line.

# %% [markdown]
# ### Extra 3: Let Python check a name for you
#
# Two small tools help you check the naming rules from Section 1.14:
#
# | Tool | What it checks |
# |---|---|
# | `"some_name".isidentifier()` | Is the text built from legal characters, and does it not start with a digit? |
# | `keyword.iskeyword("some_name")` | Is the text a keyword? |
#
# A name can be used only if the first gives `True` **and** the second gives `False`.
#
# The code uses a `for` loop, which you will learn in the chapter on flow control. For now, read it as: "for each name in the list, check it and print the answer."
#
# The last line prints the **soft keywords**. These are words like `match` and `case` that act as keywords only in certain places. Elsewhere they can still be used as names, but it is better to avoid them.

# %%
import keyword

names = ["total_marks", "_count", "1value", "first-name", "price$", "for", "Student"]

for name in names:
    usable = name.isidentifier() and not keyword.iskeyword(name)
    print(name, "->", usable)

print("Soft keywords:", keyword.softkwlist)
# Out:
# total_marks -> True
# _count -> True
# 1value -> False
# first-name -> False
# price$ -> False
# for -> False
# Student -> True
# Soft keywords: ['_', 'case', 'match', 'type']

# %% [markdown]
# ### Extra 4: Dynamic, but also strong (the last line gives an error on purpose)
#
# Python lets a name point to any type (dynamic typing). But it does not guess when you mix types that do not fit together (strong typing).
#
# - Line 1 turns the number `5` into the text `"5"` with `str()`, then joins two strings: `55`.
# - Line 2 turns the text `"5"` into the number `5` with `int()`, then adds two numbers: `10`.
# - Line 3 tries to add text and a number without converting. Python refuses and raises a `TypeError`.
#
# Some languages, such as JavaScript, would quietly turn `"5" + 5` into `"55"`. Python makes you say clearly what you want.

# %%
print("5" + str(5))   # join two strings: 55
print(int("5") + 5)   # add two numbers: 10
print("5" + 5)        # TypeError: Python will not mix a str and an int
# Out:
# 55
# 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 print("5" + str(5))   # join two strings: 55
#       2 print(int("5") + 5)   # add two numbers: 10
# ----> 3 print("5" + 5)        # TypeError: Python will not mix a str and an int
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Table of changes made to this notebook
#
# | No. | Element | In the original notebook | In this revised notebook | Type of change |
# |---|---|---|---|---|
# | 1 | "Open in Colab" badge cell | Present | Kept exactly as it was | Unchanged |
# | 2 | Title and "How this notebook is arranged" cell | Not present | Explains the layout, how to run cells, the two cells that fail on purpose, and how the flowchart steps are numbered | Added |
# | 3 | Chapter map | Not present | Table linking each book section to the examples in the notebook | Added |
# | 4 | Background for Sections 1.2 and 1.3 | Not present | Short text on interpreter and compiler with a flowchart, and a table comparing interactive mode and script mode | Added |
# | 5 | Section 1.8, calculator (Figure 1.4, four cells) | Missing | Added as Examples 1 to 4. Intro cell with an operator table, one text cell before each example, and notes after Example 4 (Python 3 division compared with C, PEP 8 spacing, a small exercise) | Added |
# | 6 | Section 1.9, `print()` (Figure 1.5) | Missing | Added as Example 5, with explanation, flowchart and the signature of `print()` | Added |
# | 7 | Section 1.10, `hello.py` one-line script | Missing | Added as Example 6, with a flowchart, and notes containing the "why use a script" list and the shell versus script table. The curly quotes of the printed code were replaced with straight quotes so the code runs | Added |
# | 8 | Section 1.11, comment with `#` over two lines | Missing | Added as Example 7, with a table comparing `#` comments and triple quotes | Added |
# | 9 | Section 1.11, triple-quoted multi-line comment | Missing | Added as Example 8, with notes explaining why the notebook shows the string, and a flowchart | Added |
# | 10 | Section 1.11.1, backslash line continuation (Figure 1.6) | Missing | Added as Example 9, with an overview table of the four ways and a flowchart of the error case | Added |
# | 11 | Section 1.11.1, implicit continuation in brackets | Missing | Added as Example 10 | Added |
# | 12 | Section 1.11.1, several statements with semicolons | Missing | Added as Example 11 | Added |
# | 13 | Section 1.11.1, "better version" with one statement per line | Missing | Added as Example 12 | Added |
# | 14 | Section 1.12, indentation | Not present | Short text summary (the book has no code here) | Added |
# | 15 | Section 1.13, `import keyword` and `print(keyword.kwlist)` | Missing | Added as Example 13, with a table of the `keyword` module, a flowchart, and notes on version differences, on `print` and `exec` not being keywords in Python 3, and a table of the 35 keywords grouped by purpose | Added |
# | 16 | Sections 1.14 and 1.15, identifiers, conventions, PEP 8 | Not present | Table of legal rules, a flowchart for checking a name, a short note on PEP and PEP 8, a table of PEP 8 naming conventions, and camelCase | Added |
# | 17 | PEP 8 versus non-PEP 8 script | The only code cell. Placed directly after the badge, with no explanation | Code and its output kept exactly. Moved to the Sections 1.14 and 1.15 position as Example 14. Text cell added before it (what, how, why, a table of the five parts, a flowchart) and notes after it (table of output lines, why `CalculateAverage` prints nothing, the meaning of the closing comment, f-strings, linters) | Code unchanged; moved; explanation added |
# | 18 | Section 1.16.1, box versus tag | Not present | Table comparing C++ and Python variables, with statically typed, dynamically typed and strongly typed explained | Added |
# | 19 | Section 1.16.2, `x = 2`, `y = x`, `y = 3` (Figure 1.7) | Missing | Added as Example 15, with a step flowchart. Curly quotes in the comments replaced with straight quotes | Added |
# | 20 | Section 1.16.2, `type()` example | Missing | Added as Example 16, with the signature of `type()` and notes with a table of common types. Curly quotes replaced with straight quotes | Added |
# | 21 | Section 1.16.2, casting `my_float` to `my_int` | Missing | Added as Example 17, with the signature of `int()`, a flowchart, and notes on id numbers and the small-integer store. Curly quotes replaced with straight quotes | Added |
# | 22 | Section 1.16.3, `x = 3` | Missing | Added as Example 18, with the three steps of an assignment and a flowchart | Added |
# | 23 | Section 1.16.4, `x = 3`, `y = 2`, `y = x` | Missing | Added as Example 19, with a flowchart. The explanation states that both names refer to the object 3 | Added |
# | 24 | Section 1.16.4, `x = x + 2` | Missing | Added as Example 20, with a flowchart | Added |
# | 25 | Section 1.16.5, variable versus identifier | Not present | Comparison table | Added |
# | 26 | Helper cell `x = None` and `del x` | Not present | Added before Example 21, so that the `NameError` appears as in the book even though earlier cells defined `x` | Added (not from the book) |
# | 27 | Section 1.16.5, `x` giving `NameError` | Missing | Added as Example 21, with a flowchart and notes on fixing the error and on "Run after" | Added |
# | 28 | Section 1.16.5, `id(10)` and `id(age)` | Missing | Added as Example 22, with a table of identity, type and value, the signature of `id()`, and a flowchart | Added |
# | 29 | Chapter summary table | Not present | One table of the main ideas | Added |
# | 30 | Beyond the Book | Not present | Four short extras: running a real `.py` file in Colab, `sep` and `end` in `print()`, checking names with `isidentifier()` and `iskeyword()`, and strong typing | Added |
# | 31 | Saved outputs | Output of the PEP 8 cell only | All code cells were run in Python 3.12 and their outputs saved. The id numbers will be different each time the notebook is run | Updated |
